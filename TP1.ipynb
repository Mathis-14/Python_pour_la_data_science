# %%
import numpy as np
rng = np.random.default_rng(seed=123456) # We set the seed to be able to retrace our results
X=rng.uniform(size=1000) # déconseille d'utiliser np.random
#pareil que rng.uniform(0,1,1000)

# %%
import seaborn as sns
sns.histplot(X)
# Out:
# <Axes: ylabel='Count'>
